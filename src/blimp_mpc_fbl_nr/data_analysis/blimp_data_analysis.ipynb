# %%
from utils import *

# %%
log_file_path = 'log1.log'
df_log = pd.read_csv(log_file_path, header=0)# Reading the .log file into a pandas DataFrame
df_log.head()# Display the first few rows to confirm successful import
# Out:
#     time        vx        vy        vz        wx        wy        wz  \
# 0  0.033  0.000173 -0.005830  0.011413  0.045307  0.001346  0.000000
# 1  0.066  0.000346 -0.011636  0.022736  0.090415  0.002686  0.000000
# 2  0.099 -0.000023 -0.006964  0.018327  0.053725 -0.000189  0.000187
# 3  0.132 -0.000388 -0.002373  0.013930  0.016172 -0.003082  0.000373
# 4  0.165 -0.000793  0.002187  0.013844 -0.021988 -0.006286  0.000370
#
#           x         y         z  ...     x_ref     y_ref  z_ref  psi_ref  \
# 0  0.800000  0.000000 -1.300000  ...  0.800000  0.000000   -1.3      0.0
# 1  0.800006 -0.000192 -1.299623  ...  0.799993  0.003318   -1.3      0.0
# 2  0.800017 -0.000577 -1.298874  ...  0.799972  0.006635   -1.3      0.0
# 3  0.800016 -0.000810 -1.298270  ...  0.799938  0.009952   -1.3      0.0
# 4  0.800004 -0.000891 -1.297811  ...  0.799890  0.013269   -1.3      0.0
#
#     x_error   y_error   z_error  psi_error  solve_time  \
# ...

# %%
calculate_overall_rmse(df_log)
# Out:
# 0.01392200406011327

# %%
df_log['solve_time'].mean() * 1e-9
# Out:
# 0.0193675511664465

# %%
# Reuse the plotting function defined earlier for the uploaded .log data
plot_adjusted_avg_and_max_xyz_vs_reference(df_log)
