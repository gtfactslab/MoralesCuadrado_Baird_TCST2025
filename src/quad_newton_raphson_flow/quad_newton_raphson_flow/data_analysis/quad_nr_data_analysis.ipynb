# %%
import pandas as pd
from utils import make_plot, rmse

# %%
log_file_path = 'log2.log'
df_log = pd.read_csv(log_file_path, header=0, dtype={'metadata': str})# Reading the .log file into a pandas DataFrame
df_log.head()# Display the first few rows to confirm successful import
# Out:
#        time         x         y         z       yaw  throttle  roll_rate  \
# 0  0.000001 -0.009592  0.022826  0.259494 -0.025538  0.721338  -0.023451
# 1  0.521393 -0.009592  0.022826  0.259494 -0.025538  0.742960  -0.036549
# 2  0.529250 -0.012411  0.019397  0.282753 -0.025318  0.760634  -0.038124
# 3  0.539220 -0.012320  0.019295  0.282605 -0.025344  0.774519  -0.038999
# 4  0.549191 -0.012240  0.019199  0.282499 -0.025365  0.785469  -0.039469
#
#    pitch_rate  yaw_rate  x_ref  y_ref  z_ref  yaw_ref  pred_time   nr_time  \
# 0   -0.034496  0.009560    0.0    0.0   -0.6      0.0   0.457014  0.457014
# 1   -0.053509  0.015855    0.0    0.0   -0.6      0.0   0.000200  0.000200
# 2   -0.066080  0.020174    0.0    0.0   -0.6      0.0   0.000263  0.000263
# 3   -0.073691  0.023215    0.0    0.0   -0.6      0.0   0.000256  0.000256
# 4   -0.078409  0.025359    0.0    0.0   -0.6      0.0   0.000212  0.000212
#
#    ctrl_callback_time              metadata
# 0            0.521380                   Sim
# 1            0.003036         jax_reg_wardi
# 2            0.003288              1x Speed
# 3            0.003359  circle_horz_ref_func
# 4            0.003014                     0

# %%
print(f"This data comes from: {df_log['metadata'][0]}")
print(f"Predictor was: {df_log['metadata'][1]}")
print(f"Speed: {df_log['metadata'][2]}")
print(f"Trajectory: {df_log['metadata'][3]}")
print(f"Mean NR computation time: {df_log['nr_time'].mean()}")
print(f"Mean NR computation freq: {1/df_log['nr_time'].mean()}")
print(f"Mean callback time: {df_log['ctrl_callback_time'].mean()}")
print(f"RMSE: {rmse(df_log)}")
# Out:
# This data comes from: Sim
# Predictor was: jax_reg_wardi
# Speed: 1x Speed
# Trajectory: circle_horz_ref_func
# Mean NR computation time: 0.0005360051827389876
# Mean NR computation freq: 1865.6536022469
# Mean callback time: 0.0037618290268091447
# RMSE: 0.11339636698379761

# %%
# Reuse the plotting function defined earlier for the uploaded .log data
make_plot(df_log)
